# %%
import matplotlib.pyplot as plt
import cv2
import sys
sys.path.append('../')
from tracker_gen import *
from utils import *

# %%
model_path='../model/test-best-v5m-2.pt'
tracker=Tracker(model_path)

# %%
video_path='../input-video/test-adios-input.mp4'
frames=read_video(video_path)

# %%
stub_path='../track-stub/test.pkl'
tracks=tracker.tracks_generator(frames,True,stub_path)
# Out:
# 0: 416x736 13 players, 6.8ms
# 1: 416x736 12 players, 6.8ms
# 2: 416x736 11 players, 6.8ms
# 3: 416x736 12 players, 6.8ms
# 4: 416x736 12 players, 6.8ms
# 5: 416x736 12 players, 6.8ms
# 6: 416x736 12 players, 6.8ms
# 7: 416x736 12 players, 6.8ms
# 8: 416x736 12 players, 6.8ms
# 9: 416x736 12 players, 6.8ms
# 10: 416x736 12 players, 6.8ms
# 11: 416x736 13 players, 6.8ms
# 12: 416x736 14 players, 6.8ms
# 13: 416x736 14 players, 6.8ms
# 14: 416x736 13 players, 6.8ms
# 15: 416x736 12 players, 6.8ms
# 16: 416x736 12 players, 6.8ms
# 17: 416x736 12 players, 6.8ms
# 18: 416x736 12 players, 6.8ms
# 19: 416x736 12 players, 6.8ms
# 20: 416x736 13 players, 6.8ms
# 21: 416x736 12 players, 6.8ms
# 22: 416x736 14 players, 6.8ms
# 23: 416x736 14 players, 6.8ms
# 24: 416x736 14 players, 6.8ms
# 25: 416x736 12 players, 6.8ms
# 26: 416x736 13 players, 6.8ms
# 27: 416x736 12 players, 6.8ms
# 28: 416x736 12 players, 6.8ms
# 29: 416x736 12 players, 6.8ms
# ...

# %%
tracks['players']
# Out:
# [{8: {'bbox': [1088.775634765625,
#     146.1834716796875,
#     1099.2093505859375,
#     183.63465881347656]},
#   70: {'bbox': [81.72921752929688,
#     307.7707824707031,
#     137.14588928222656,
#     427.57366943359375]}},
#  {8: {'bbox': [1089.8470458984375,
#     145.90313720703125,
#     1099.9822998046875,
#     182.62452697753906]},
#   70: {'bbox': [85.92997741699219,
#     305.0887756347656,
#     141.56655883789062,
#     427.0079345703125]},
#   172: {'bbox': [791.2841796875,
#     170.98275756835938,
#     820.8414916992188,
#     246.3477783203125]},
#   173: {'bbox': [1070.622802734375,
#     168.8529815673828,
#     1094.7303466796875,
#     220.8970489501953]},
#   174: {'bbox': [753.1572875976562,
#     129.6559600830078,
#     767.9149780273438,
#     183.9893035888672]},
#   175: {'bbox': [851.7039794921875,
#     185.97898864746094,
#     895.740234375,
#     247.19110107421875]},
#   176: {'bbox': [1143.15380859375,
#     171.6793670654297,
# ...
