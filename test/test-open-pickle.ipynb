# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import sys
sys.path.append('../')
from utils import *

# %%
with open('../track-stub/test-stub-v5-2-2(.4conf).pkl','rb') as load:
    tracks=pickle.load(load)

# %%
tracks['players'][0]
# Out:
# {1: {'bbox': [90.87799072265625,
#    303.9674072265625,
#    139.79237365722656,
#    426.89593505859375],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  2: {'bbox': [790.737060546875,
#    170.85968017578125,
#    820.19677734375,
#    246.01422119140625],
#   'team': 1,
#   'team_color': array([215.14444444, 101.58863636, 178.71273259])},
#  3: {'bbox': [1068.319091796875,
#    169.07705688476562,
#    1092.7960205078125,
#    221.89402770996094],
#   'team': 1,
#   'team_color': array([215.14444444, 101.58863636, 178.71273259])},
#  4: {'bbox': [752.807373046875,
#    129.52565002441406,
#    767.5853271484375,
#    183.93797302246094],
#   'team': 1,
#   'team_color': array([215.14444444, 101.58863636, 178.71273259])},
#  5: {'bbox': [851.50830078125,
#    186.23968505859375,
#    893.860107421875,
#    245.1192626953125],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  6: {'bbox': [1143.3548583984375,
#    171.56478881835938,
#    1157.886962890625,
#    213.72315979003906],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  7: {'bbox': [910.0174560546875,
#    123.80590057373047,
#    924.1257934570312,
#    167.348876953125],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  8: {'bbox': [1090.3013916015625,
#    145.6024169921875,
#    1099.1910400390625,
#    181.51646423339844],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  9: {'bbox': [1003.9576416015625,
#    171.02671813964844,
#    1023.7088623046875,
#    235.5216522216797],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029]),
#   'has_ball': True},
#  10: {'bbox': [903.1624145507812,
#    110.47346496582031,
#    916.030517578125,
#    145.03468322753906],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  11: {'bbox': [1024.455322265625,
#    146.73583984375,
#    1037.427001953125,
#    192.17916870117188],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  12: {'bbox': [743.3189697265625,
#    120.27752685546875,
#    757.8132934570312,
#    169.10137939453125],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])},
#  13: {'bbox': [1017.1376953125,
#    171.15090942382812,
#    1030.25927734375,
#    232.7385711669922],
#   'team': 0,
#   'team_color': array([ 67.92471103, 138.39328804, 163.17620029])}}

# %%
frames=read_video('../input-video/test-adios-input.mp4')

# %%
plt.imshow(cv2.cvtColor(frames[0],cv2.COLOR_BGR2RGB))
